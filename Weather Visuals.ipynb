# %%
import pandas as pd
import numpy as np
import plotly.graph_objs as go
import plotly.plotly as py
from plotly.offline import iplot, init_notebook_mode

import cufflinks
cufflinks.go_offline(connected=True)
init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
# %store -r

# %%
test_visual = pd.DataFrame(test_vis, index=features)
# Out:
#                           0
# humidity           0.081363
# moonPhase          0.035591
# precipIntensity    0.171351
# precipProbability  0.009267
# pressure           0.128553
# sunriseTime        0.017975
# temperature        0.098689
# windBearing        0.029847
# windSpeed          0.068953
# daylightHours      0.090923
# tempChange6        0.079279
# tempChange12       0.085043
# tempChange24       0.014770
# pressureChange6    0.031686
# pressureChange12   0.022928
# pressureChange24   0.033782

# %%
# bar of feature importances

# %%
test_visual.iplot(kind='bar', xTitle='Features',
                    linecolor='blue', 
                    yTitle='Importance (%)',
                    ticks='inside',
                    title="Feature Importance")

# %%
# Scatter of pressure v temp seperated by season

# %%
model_copy['summary'].unique()
# Out:
# array(['Overcast', 'Rain', 'Mostly Cloudy', 'Clear', 'Partly Cloudy',
#        'Snow', 'Cloudy'], dtype=object)

# %%
rainy = model_copy[model_copy.summary == "Rain"]
rainy.head()
# Out:
#                      apparentTemperature  cloudCover  dewPoint  humidity  \
# time
# 2017-08-19 00:00:00                71.68         NaN     67.26      0.89
# 2017-08-22 19:48:20                71.62         NaN     67.11      0.88
# 2017-08-19 00:00:00                71.68         NaN     67.26      0.89
# 2017-08-22 19:48:20                71.62         NaN     67.11      0.88
# 2017-09-03 06:19:51                54.06         NaN     48.51      0.81
#
#                      icon  moonPhase  precipIntensity  precipProbability  \
# time
# 2017-08-19 00:00:00  rain       0.93           0.0198               0.38
# 2017-08-22 19:48:20  rain       0.04           0.0626               0.74
# 2017-08-19 00:00:00  rain       0.93           0.0198               0.38
# 2017-08-22 19:48:20  rain       0.04           0.0626               0.74
# 2017-09-03 06:19:51  rain       0.41           0.0074               0.64
#
#                     precipType  pressure  ... windBearing  windGust  \
# ...

# %%
text = [f'{t}'for t in (rainy['time'])]


rainy.iplot(
    x='pressure',
    y='temperature',
    opacity=0.8,
    text=text,
    mode='markers',
    theme='pearl',
    layout=dict(
        xaxis=dict(type='log', title='Pressure'),
        yaxis=dict(title='Temperature'),
        title='Pressure v Temp'))

# %%
py.iplot(
    {
        'data': [
            {
                'x': weather_df_copy[weather_df_copy['summary']==outlook]['pressure'],
                'y': weather_df_copy[weather_df_copy['summary']==outlook]['temperature'],
                'name': outlook, 'mode': 'markers',
            } for outlook in ['Rain', 'Clear', 'Snow', 'Overcast']
        ],
        'layout': {
            'xaxis': {'title': 'Pressure in Pa', 'type': 'log'},
            'yaxis': {'title': "Temperature in F"}
        }
})
# Out:
# Aw, snap! We didn't get a username with your request.
#
# Don't have an account? https://plot.ly/api_signup
#
# Questions? accounts@plot.ly
# ---------------------------------------------------------------------------
# PlotlyError                               Traceback (most recent call last)
# <ipython-input-81-4e24cace97f9> in <module>
#      10         'layout': {
#      11             'xaxis': {'title': 'Pressure in Pa', 'type': 'log'},
# ---> 12             'yaxis': {'title': "Temperature in F"}
#      13         }
#      14 })
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\plotly\plotly\plotly.py in iplot(figure_or_data, **plot_options)
#     186         embed_options['height'] = str(embed_options['height']) + 'px'
#     187
# --> 188     return tools.embed(url, **embed_options)
#     189
#     190
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\plotly\tools.py in embed(file_owner_or_url, file_id, width, height)
#     399         else:
# ...
